# %%
import pandas as pd

# %%
TN_demo = pd.read_excel('../data/tennesseecountydemographics2021.xlsx', sheet_name='Data')

# %%
income_df = pd.read_excel('../data/tennessee2021householdincome.xlsx', sheet_name='Data')

# %%
income_df
# Out:
#                                 Unnamed: 0 Anderson County, Tennessee  \
# 0                                      NaN                 Households
# 1                                    Label                   Estimate
# 2                                    Total                     31,735
# 3                        Less than $10,000                       8.8%
# 4                       $10,000 to $14,999                       4.4%
# 5                       $15,000 to $24,999                       7.6%
# 6                       $25,000 to $34,999                       8.2%
# 7                       $35,000 to $49,999                      14.9%
# 8                       $50,000 to $74,999                      15.0%
# 9                       $75,000 to $99,999                      15.8%
# 10                    $100,000 to $149,999                      15.3%
# 11                    $150,000 to $199,999                       6.3%
# 12                        $200,000 or more                       3.8%
# 13                 Median income (dollars)                     60,364
# 14                   Mean income (dollars)                     75,147
# 15                       PERCENT ALLOCATED                        NaN
# 16  Household income in the past 12 months                      41.9%
# 17     Family income in the past 12 months                        (X)
# 18  Nonfamily income in the past 12 months                        (X)
#
#          Unnamed: 2 Unnamed: 3       Unnamed: 4               Unnamed: 5  \
# 0               NaN   Families              NaN  Married-couple families
# 1   Margin of Error   Estimate  Margin of Error                 Estimate
# 2            ±1,319     19,979           ±1,830                        N
# 3              ±3.1       4.6%             ±2.5                        N
# 4              ±1.7       1.6%             ±1.1                        N
# 5              ±2.5       3.5%             ±2.0                        N
# 6              ±2.7       6.3%             ±3.2                        N
# 7              ±3.8      14.2%             ±4.5                        N
# 8              ±3.1      17.5%             ±4.3                        N
# 9              ±3.2      19.6%             ±4.1                        N
# 10             ±3.4      19.2%             ±4.9                        N
# 11             ±1.7       7.9%             ±2.6                        N
# 12             ±1.5       5.6%             ±2.3                        N
# 13           ±9,111     77,754           ±5,470                   91,057
# 14           ±6,027     91,205           ±8,676                        N
# 15              NaN        NaN              NaN                      NaN
# 16              (X)        (X)              (X)                      (X)
# 17              (X)      46.6%              (X)                      (X)
# 18              (X)        (X)              (X)                      (X)
#
#          Unnamed: 6            Unnamed: 7       Unnamed: 8  \
# 0               NaN  Nonfamily households              NaN
# 1   Margin of Error              Estimate  Margin of Error
# 2                 N                11,756           ±1,455
# 3                 N                 16.3%             ±6.2
# 4                 N                  8.7%             ±4.3
# 5                 N                 15.8%             ±5.6
# 6                 N                 12.8%             ±5.5
# 7                 N                 17.2%             ±6.5
# 8                 N                 11.6%             ±5.0
# 9                 N                  8.4%             ±5.2
# 10                N                  5.9%             ±4.2
# 11                N                  2.7%             ±2.8
# 12                N                  0.7%             ±1.1
# 13           ±7,775                32,096           ±5,363
# 14                N                43,647           ±6,502
# 15              NaN                   NaN              NaN
# 16              (X)                   (X)              (X)
# 17              (X)                   (X)              (X)
# 18              (X)                 32.9%              (X)
#
#    Blount County, Tennessee  ...          Unnamed: 151     Unnamed: 152  \
# 0                Households  ...  Nonfamily households              NaN
# 1                  Estimate  ...              Estimate  Margin of Error
# 2                    55,446  ...                18,585           ±2,495
# 3                      3.5%  ...                  5.3%             ±3.1
# 4                      4.1%  ...                  3.9%             ±2.7
# 5                      6.7%  ...                  6.3%             ±3.5
# 6                      9.4%  ...                  9.9%             ±3.6
# 7                     14.8%  ...                 17.6%             ±5.7
# 8                     22.0%  ...                 23.9%             ±5.5
# 9                     12.6%  ...                 11.3%             ±5.4
# 10                    18.9%  ...                 10.1%             ±4.6
# 11                     3.5%  ...                  7.1%             ±4.0
# 12                     4.4%  ...                  4.4%             ±1.9
# 13                   62,102  ...                55,378           ±5,556
# 14                   82,281  ...                77,214           ±8,100
# 15                      NaN  ...                   NaN              NaN
# 16                    33.8%  ...                   (X)              (X)
# 17                      (X)  ...                   (X)              (X)
# 18                      (X)  ...                 31.5%              (X)
#
#    Wilson County, Tennessee     Unnamed: 154 Unnamed: 155     Unnamed: 156  \
# 0                Households              NaN     Families              NaN
# 1                  Estimate  Margin of Error     Estimate  Margin of Error
# 2                    55,047           ±1,881       38,063           ±2,177
# 3                      4.8%             ±1.8         3.5%             ±2.2
# 4                      1.7%             ±0.8         0.8%             ±0.8
# 5                      6.0%             ±1.8         3.5%             ±1.7
# 6                      4.8%             ±1.8         3.9%             ±1.6
# 7                     11.6%             ±2.7         6.5%             ±2.0
# 8                     17.5%             ±3.2        15.9%             ±3.9
# 9                     12.3%             ±2.6        15.5%             ±3.3
# 10                    21.9%             ±3.4        27.1%             ±4.5
# 11                    10.0%             ±2.4        11.6%             ±3.5
# 12                     9.4%             ±2.4        11.6%             ±3.1
# 13                   80,960           ±7,246      100,358           ±8,828
# 14                   99,591           ±6,914      114,849           ±9,018
# 15                      NaN              NaN          NaN              NaN
# 16                    33.6%              (X)          (X)              (X)
# 17                      (X)              (X)        33.9%              (X)
# 18                      (X)              (X)          (X)              (X)
#
#                Unnamed: 157     Unnamed: 158          Unnamed: 159  \
# 0   Married-couple families              NaN  Nonfamily households
# 1                  Estimate  Margin of Error              Estimate
# 2                         N                N                16,984
# 3                         N                N                 10.2%
# 4                         N                N                  3.5%
# 5                         N                N                 14.0%
# 6                         N                N                  7.9%
# 7                         N                N                 24.3%
# 8                         N                N                 17.2%
# 9                         N                N                  5.0%
# 10                        N                N                  9.4%
# 11                        N                N                  4.6%
# 12                        N                N                  3.8%
# 13                  111,369           ±9,638                41,036
# 14                        N                N                58,956
# 15                      NaN              NaN                   NaN
# 16                      (X)              (X)                   (X)
# 17                      (X)              (X)                   (X)
# 18                      (X)              (X)                 29.1%
#
#        Unnamed: 160
# 0               NaN
# 1   Margin of Error
# 2            ±1,956
# 3              ±4.3
# 4              ±2.1
# 5              ±5.6
# 6              ±4.0
# 7              ±6.8
# 8              ±5.4
# 9              ±2.7
# 10             ±4.7
# 11             ±3.2
# 12             ±3.6
# 13           ±3,301
# 14          ±10,145
# 15              NaN
# 16              (X)
# 17              (X)
# 18              (X)
#
# [19 rows x 161 columns]

# %%
TN_demo
# Out:
#                          Unnamed: 0 Anderson County, Tennessee  \
# 0                             Label                   Estimate
# 1                       SEX AND AGE                        NaN
# 2                  Total population                     77,576
# 3                              Male                     38,441
# 4                            Female                     39,135
# ..                              ...                        ...
# 90              Total housing units                     35,532
# 91   CITIZEN, VOTING AGE POPULATION                        NaN
# 92  Citizen, 18 and over population                     59,726
# 93                             Male                     28,992
# 94                           Female                     30,734
#
#          Unnamed: 2 Unnamed: 3               Unnamed: 4  \
# 0   Margin of Error    Percent  Percent Margin of Error
# 1               NaN        NaN                      NaN
# 2             *****     77,576                      (X)
# 3              ±533      49.6%                     ±0.7
# 4              ±533      50.4%                     ±0.7
# ..              ...        ...                      ...
# 90             ±428        (X)                      (X)
# 91              NaN        NaN                      NaN
# 92             ±544     59,726                      (X)
# 93             ±415      48.5%                     ±0.6
# 94             ±446      51.5%                     ±0.6
#
#    Blount County, Tennessee       Unnamed: 6 Unnamed: 7  \
# 0                  Estimate  Margin of Error    Percent
# 1                       NaN              NaN        NaN
# 2                   137,605            *****    137,605
# 3                    66,943             ±594      48.6%
# 4                    70,662             ±594      51.4%
# ..                      ...              ...        ...
# 90                   60,847             ±459        (X)
# 91                      NaN              NaN        NaN
# 92                  108,095             ±979    108,095
# 93                   51,559             ±505      47.7%
# 94                   56,536             ±852      52.3%
#
#                  Unnamed: 8 Bradley County, Tennessee  ... Unnamed: 71  \
# 0   Percent Margin of Error                  Estimate  ...     Percent
# 1                       NaN                       NaN  ...         NaN
# 2                       (X)                   110,162  ...     134,236
# 3                      ±0.4                    53,995  ...       49.2%
# 4                      ±0.4                    56,167  ...       50.8%
# ..                      ...                       ...  ...         ...
# 90                      (X)                    45,369  ...         (X)
# 91                      NaN                       NaN  ...         NaN
# 92                      (X)                    84,172  ...     107,649
# 93                     ±0.5                    40,994  ...       48.3%
# 94                     ±0.5                    43,178  ...       51.7%
#
#                 Unnamed: 72 Williamson County, Tennessee      Unnamed: 74  \
# 0   Percent Margin of Error                     Estimate  Margin of Error
# 1                       NaN                          NaN              NaN
# 2                       (X)                      255,735            *****
# 3                      ±0.4                      125,693             ±936
# 4                      ±0.4                      130,042             ±936
# ..                      ...                          ...              ...
# 90                      (X)                       94,671              ±80
# 91                      NaN                          NaN              NaN
# 92                      (X)                      182,064           ±1,848
# 93                     ±0.2                       87,203           ±1,699
# 94                     ±0.2                       94,861             ±849
#
#    Unnamed: 75              Unnamed: 76 Wilson County, Tennessee  \
# 0      Percent  Percent Margin of Error                 Estimate
# 1          NaN                      NaN                      NaN
# 2      255,735                      (X)                  151,917
# 3        49.1%                     ±0.4                   76,547
# 4        50.9%                     ±0.4                   75,370
# ..         ...                      ...                      ...
# 90         (X)                      (X)                   60,907
# 91         NaN                      NaN                      NaN
# 92     182,064                      (X)                  111,928
# 93       47.9%                     ±0.5                   54,838
# 94       52.1%                     ±0.5                   57,090
#
#         Unnamed: 78 Unnamed: 79              Unnamed: 80
# 0   Margin of Error     Percent  Percent Margin of Error
# 1               NaN         NaN                      NaN
# 2             *****     151,917                      (X)
# 3              ±994       50.4%                     ±0.7
# 4              ±994       49.6%                     ±0.7
# ..              ...         ...                      ...
# 90             ±434         (X)                      (X)
# 91              NaN         NaN                      NaN
# 92           ±1,386     111,928                      (X)
# 93             ±919       49.0%                     ±0.6
# 94             ±989       51.0%                     ±0.6
#
# [95 rows x 81 columns]
