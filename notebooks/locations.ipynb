# %%
import pandas as pd

# %%
df = pd.read_csv('../data/top_food_chains_in_tennessee_usa.csv')
df
# Out:
#      Store No.                          Name   Latitude  Longitude  \
# 0        11973               Madisonvle-H411  35.511170 -84.367407
# 1       037154           Taco Bell Kingsport  36.552304 -82.626715
# 2       034684            Taco Bell Humboldt  35.833557 -88.915649
# 3        10725              Lewisburg/Elling  35.446775 -86.775723
# 4         6253                 Sweetwtr-I-75  35.599205 -84.510459
# ...        ...                           ...        ...        ...
# 5633    515761   A&w Restaurants Sevierville  35.863789 -83.544746
# 5634    516579      A&w Restaurants Savannah  35.213533 -88.245210
# 5635    515644    A&w Restaurants Sweetwater  35.597468 -84.498707
# 5636    515919   A&w Restaurants White House  36.468717 -86.677374
# 5637    515743  A&w Restaurants Madisonville  35.531098 -84.341118
#
#                                                Address  \
# 0            840 Patterson St, Madisonville, TN, 37354
# ...

# %%
closed_stores_count = len(df[df['Status'] != 'Open'])

# %%
closed_stores_count
# Out:
# 62

# %%
closed_stores_df = df[df['Status'] != 'Open']
closed_stores_df
# Out:
#      Store No.                                       Name   Latitude  \
# 162       9954                   Burger King 4933 Main St  35.774900
# 498       5662             Burger King 1350 Sycamore View  35.162073
# 514      60233       Burger King 1153 N. Houston Levee Rd  35.156710
# 515      80969                   Burger King 10013 Hwy 64  35.205649
# 526      10098           Burger King 2009 Columbia Avenue  35.895813
# ...        ...                                        ...        ...
# 5288      3014                         Shoney's Nashville  36.217869
# 5291      2971                    Shoney's Goodlettsville  36.325606
# 5293      3055                        Shoney's Cookeville  36.140912
# 5294      3012                       Shoney's Clarksville  36.540436
# 5495       NaN  Mcghee Tyson Airport - Temporarily Closed  35.806582
#
#       Longitude                                          Address  \
# 162  -86.916502             4933 Main St, Spring Hill, TN, 37174
# ...

# %%
columns_to_drop = ['Phone', 'Open Hours', 'Updated Date', 'Country']
new_df = df.drop(columns=columns_to_drop)

# %%
new_df
# Out:
#      Store No.                          Name   Latitude  Longitude  \
# 0        11973               Madisonvle-H411  35.511170 -84.367407
# 1       037154           Taco Bell Kingsport  36.552304 -82.626715
# 2       034684            Taco Bell Humboldt  35.833557 -88.915649
# 3        10725              Lewisburg/Elling  35.446775 -86.775723
# 4         6253                 Sweetwtr-I-75  35.599205 -84.510459
# ...        ...                           ...        ...        ...
# 5633    515761   A&w Restaurants Sevierville  35.863789 -83.544746
# 5634    516579      A&w Restaurants Savannah  35.213533 -88.245210
# 5635    515644    A&w Restaurants Sweetwater  35.597468 -84.498707
# 5636    515919   A&w Restaurants White House  36.468717 -86.677374
# 5637    515743  A&w Restaurants Madisonville  35.531098 -84.341118
#
#                                                Address  \
# 0            840 Patterson St, Madisonville, TN, 37354
# ...
